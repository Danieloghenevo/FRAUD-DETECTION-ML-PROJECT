# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data/mob_money_mixed_data_2.csv')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
df.head()
# Out:
#      merchant    customer_name               customer_email  \
# 0  BLENET LTD  Emmanuel Norman        iamnormkay@icloud.com
# 1  BLENET LTD    Edward Gyamfi     gyamfiedward98@gmail.com
# 2  BLENET LTD       Elom Ohene  humanitarianalarm@gmail.com
# 3  BLENET LTD   Benneth Pascal           mrpubenr@gmail.com
# 4  BLENET LTD   Benneth Pascal           mrpubenr@gmail.com
#
#    customer_phone_number payment_reference transaction_reference  \
# 0           2.335435e+11         923438867   KPY-CA-5xlpa6ZxSxHf
# 1           2.335575e+11         923446863   KPY-CA-bVBQDQuNVhsb
# 2           2.332457e+11         923448600   KPY-CA-YtBlORY4dc0S
# 3           2.335582e+11         923449039   KPY-CA-s93p6xaZ3TOJ
# 4           2.335582e+11         923449546   KPY-CA-UjVz7bbxlKV0
#
#    merchant_bears_cost   payment_created_at payment_completed_at  \
# 0                    1  2024-08-26 16:03:35  2024-08-26 16:15:17
# 1                    1  2024-08-26 16:17:07  2024-08-26 16:17:41
# 2                    1  2024-08-26 16:20:13  2024-08-26 16:21:04
# 3                    1  2024-08-26 16:20:50  2024-08-26 16:37:42
# 4                    1  2024-08-26 16:21:46  2024-08-26 16:22:39
#
#     payment_updated_at  for_disbursement_wallet allowed_payment_methods  \
# 0  2024-08-26 16:15:17                        0                     NaN
# 1  2024-08-26 16:17:41                        0                     NaN
# 2  2024-08-26 16:21:04                        0                     NaN
# 3  2024-08-26 16:37:42                        0                     NaN
# 4  2024-08-26 16:22:39                        0                     NaN
#
#   account_created_date  account_risk_level payment_source_type processor  \
# 0  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 1  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 2  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 3  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 4  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
#
#   payment_status payment_channel  amount_collected  payment_reversals_type  \
# 0         failed             api              0.00                       0
# 1        success             api            156.02                       0
# 2        success             api            156.02                       0
# 3         failed             api              0.00                       0
# 4        success             api            506.00                       0
#
#   currency  mobile_number_for_mobile_money mobile_network_provider  \
# 0      GHS                    233543521075                     MTN
# 1      GHS                    233557469987                     MTN
# 2      GHS                    233245689134                     MTN
# 3      GHS                    233272525000                  Airtel
# 4      GHS                    233243721306                     MTN
#
#           processor_response       kora_translated_processor_response  amount  \
# 0        Transaction failed.  Charge attempt failed, please try again  468.05
# 1    Transaction successful.                        Charge successful  156.02
# 2    Transaction successful.                        Charge successful  156.02
# 3  Transaction id is invalid  Charge attempt failed, please try again  506.00
# 4    Transaction successful.                        Charge successful  506.00
#
#    auth_model            tran_date  is_fraud
# 0  STK_PROMPT  2024-08-26 16:03:35         0
# 1  STK_PROMPT  2024-08-26 16:17:07         0
# 2  STK_PROMPT  2024-08-26 16:20:13         0
# 3  STK_PROMPT  2024-08-26 16:20:50         0
# 4  STK_PROMPT  2024-08-26 16:21:46         0

# %%
new_order = ['transaction_reference', 'payment_reference', 'merchant', 
             'customer_name', 'customer_email', 'customer_phone_number',
             'merchant_bears_cost', 'tran_date', 'payment_created_at', 
             'payment_completed_at', 'payment_updated_at', 'for_disbursement_wallet',
             'allowed_payment_methods', 'account_created_date', 'account_risk_level',
             'payment_source_type', 'processor', 'payment_status', 'payment_channel',
             'payment_reversals_type', 'currency', 'auth_model',
             'mobile_number_for_mobile_money', 'mobile_network_provider',
             'processor_response', 'kora_translated_processor_response', 'amount',
             'amount_collected', 'is_fraud']
df = df[new_order]

# %%
df.head()
# Out:
#   transaction_reference payment_reference    merchant    customer_name  \
# 0   KPY-CA-5xlpa6ZxSxHf         923438867  BLENET LTD  Emmanuel Norman
# 1   KPY-CA-bVBQDQuNVhsb         923446863  BLENET LTD    Edward Gyamfi
# 2   KPY-CA-YtBlORY4dc0S         923448600  BLENET LTD       Elom Ohene
# 3   KPY-CA-s93p6xaZ3TOJ         923449039  BLENET LTD   Benneth Pascal
# 4   KPY-CA-UjVz7bbxlKV0         923449546  BLENET LTD   Benneth Pascal
#
#                 customer_email  customer_phone_number  merchant_bears_cost  \
# 0        iamnormkay@icloud.com           2.335435e+11                    1
# 1     gyamfiedward98@gmail.com           2.335575e+11                    1
# 2  humanitarianalarm@gmail.com           2.332457e+11                    1
# 3           mrpubenr@gmail.com           2.335582e+11                    1
# 4           mrpubenr@gmail.com           2.335582e+11                    1
#
#              tran_date   payment_created_at payment_completed_at  \
# 0  2024-08-26 16:03:35  2024-08-26 16:03:35  2024-08-26 16:15:17
# 1  2024-08-26 16:17:07  2024-08-26 16:17:07  2024-08-26 16:17:41
# 2  2024-08-26 16:20:13  2024-08-26 16:20:13  2024-08-26 16:21:04
# 3  2024-08-26 16:20:50  2024-08-26 16:20:50  2024-08-26 16:37:42
# 4  2024-08-26 16:21:46  2024-08-26 16:21:46  2024-08-26 16:22:39
#
#     payment_updated_at  for_disbursement_wallet allowed_payment_methods  \
# 0  2024-08-26 16:15:17                        0                     NaN
# 1  2024-08-26 16:17:41                        0                     NaN
# 2  2024-08-26 16:21:04                        0                     NaN
# 3  2024-08-26 16:37:42                        0                     NaN
# 4  2024-08-26 16:22:39                        0                     NaN
#
#   account_created_date  account_risk_level payment_source_type processor  \
# 0  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 1  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 2  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 3  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 4  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
#
#   payment_status payment_channel  payment_reversals_type currency  auth_model  \
# 0         failed             api                       0      GHS  STK_PROMPT
# 1        success             api                       0      GHS  STK_PROMPT
# 2        success             api                       0      GHS  STK_PROMPT
# 3         failed             api                       0      GHS  STK_PROMPT
# 4        success             api                       0      GHS  STK_PROMPT
#
#    mobile_number_for_mobile_money mobile_network_provider  \
# 0                    233543521075                     MTN
# 1                    233557469987                     MTN
# 2                    233245689134                     MTN
# 3                    233272525000                  Airtel
# 4                    233243721306                     MTN
#
#           processor_response       kora_translated_processor_response  amount  \
# 0        Transaction failed.  Charge attempt failed, please try again  468.05
# 1    Transaction successful.                        Charge successful  156.02
# 2    Transaction successful.                        Charge successful  156.02
# 3  Transaction id is invalid  Charge attempt failed, please try again  506.00
# 4    Transaction successful.                        Charge successful  506.00
#
#    amount_collected  is_fraud
# 0              0.00         0
# 1            156.02         0
# 2            156.02         0
# 3              0.00         0
# 4            506.00         0

# %%
df['customer_phone_number'] = df['customer_phone_number'].astype(str)
df.head()
# Out:
#   transaction_reference payment_reference    merchant    customer_name  \
# 0   KPY-CA-5xlpa6ZxSxHf         923438867  BLENET LTD  Emmanuel Norman
# 1   KPY-CA-bVBQDQuNVhsb         923446863  BLENET LTD    Edward Gyamfi
# 2   KPY-CA-YtBlORY4dc0S         923448600  BLENET LTD       Elom Ohene
# 3   KPY-CA-s93p6xaZ3TOJ         923449039  BLENET LTD   Benneth Pascal
# 4   KPY-CA-UjVz7bbxlKV0         923449546  BLENET LTD   Benneth Pascal
#
#                 customer_email customer_phone_number  merchant_bears_cost  \
# 0        iamnormkay@icloud.com        233543521075.0                    1
# 1     gyamfiedward98@gmail.com        233557469987.0                    1
# 2  humanitarianalarm@gmail.com        233245689134.0                    1
# 3           mrpubenr@gmail.com        233558163994.0                    1
# 4           mrpubenr@gmail.com        233558163994.0                    1
#
#              tran_date   payment_created_at payment_completed_at  \
# 0  2024-08-26 16:03:35  2024-08-26 16:03:35  2024-08-26 16:15:17
# 1  2024-08-26 16:17:07  2024-08-26 16:17:07  2024-08-26 16:17:41
# 2  2024-08-26 16:20:13  2024-08-26 16:20:13  2024-08-26 16:21:04
# 3  2024-08-26 16:20:50  2024-08-26 16:20:50  2024-08-26 16:37:42
# 4  2024-08-26 16:21:46  2024-08-26 16:21:46  2024-08-26 16:22:39
#
#     payment_updated_at  for_disbursement_wallet allowed_payment_methods  \
# 0  2024-08-26 16:15:17                        0                     NaN
# 1  2024-08-26 16:17:41                        0                     NaN
# 2  2024-08-26 16:21:04                        0                     NaN
# 3  2024-08-26 16:37:42                        0                     NaN
# 4  2024-08-26 16:22:39                        0                     NaN
#
#   account_created_date  account_risk_level payment_source_type processor  \
# 0  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 1  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 2  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 3  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
# 4  2023-04-26 10:54:42  above_average_risk        mobile_money     nsano
#
#   payment_status payment_channel  payment_reversals_type currency  auth_model  \
# 0         failed             api                       0      GHS  STK_PROMPT
# 1        success             api                       0      GHS  STK_PROMPT
# 2        success             api                       0      GHS  STK_PROMPT
# 3         failed             api                       0      GHS  STK_PROMPT
# 4        success             api                       0      GHS  STK_PROMPT
#
#    mobile_number_for_mobile_money mobile_network_provider  \
# 0                    233543521075                     MTN
# 1                    233557469987                     MTN
# 2                    233245689134                     MTN
# 3                    233272525000                  Airtel
# 4                    233243721306                     MTN
#
#           processor_response       kora_translated_processor_response  amount  \
# 0        Transaction failed.  Charge attempt failed, please try again  468.05
# 1    Transaction successful.                        Charge successful  156.02
# 2    Transaction successful.                        Charge successful  156.02
# 3  Transaction id is invalid  Charge attempt failed, please try again  506.00
# 4    Transaction successful.                        Charge successful  506.00
#
#    amount_collected  is_fraud
# 0              0.00         0
# 1            156.02         0
# 2            156.02         0
# 3              0.00         0
# 4            506.00         0

# %%
df.isna().sum()
# Out:
# transaction_reference                      0
# payment_reference                          0
# merchant                                   0
# customer_name                              0
# customer_email                             0
# customer_phone_number                      0
# merchant_bears_cost                        0
# tran_date                                  0
# payment_created_at                         0
# payment_completed_at                   69239
# payment_updated_at                         0
# for_disbursement_wallet                    0
# allowed_payment_methods               323077
# account_created_date                       0
# account_risk_level                         0
# payment_source_type                        0
# processor                                  0
# payment_status                             0
# payment_channel                            0
# payment_reversals_type                     0
# currency                                   0
# auth_model                                 0
# mobile_number_for_mobile_money             0
# mobile_network_provider                    0
# processor_response                         0
# kora_translated_processor_response         0
# amount                                     0
# amount_collected                           0
# is_fraud                                   0
# dtype: int64

# %%
df[df['is_fraud']==1].isna().sum()
# Out:
# transaction_reference                     0
# payment_reference                         0
# merchant                                  0
# customer_name                             0
# customer_email                            0
# customer_phone_number                     0
# merchant_bears_cost                       0
# tran_date                                 0
# payment_created_at                        0
# payment_completed_at                  55894
# payment_updated_at                        0
# for_disbursement_wallet                   0
# allowed_payment_methods               87322
# account_created_date                      0
# account_risk_level                        0
# payment_source_type                       0
# processor                                 0
# payment_status                            0
# payment_channel                           0
# payment_reversals_type                    0
# currency                                  0
# auth_model                                0
# mobile_number_for_mobile_money            0
# mobile_network_provider                   0
# processor_response                        0
# kora_translated_processor_response        0
# amount                                    0
# amount_collected                          0
# is_fraud                                  0
# dtype: int64

# %%
df=df.drop(columns=['allowed_payment_methods', 'payment_completed_at'], axis=1)
df.columns
# Out:
# Index(['transaction_reference', 'payment_reference', 'merchant',
#        'customer_name', 'customer_email', 'customer_phone_number',
#        'merchant_bears_cost', 'tran_date', 'payment_created_at',
#        'payment_updated_at', 'for_disbursement_wallet', 'account_created_date',
#        'account_risk_level', 'payment_source_type', 'processor',
#        'payment_status', 'payment_channel', 'payment_reversals_type',
#        'currency', 'auth_model', 'mobile_number_for_mobile_money',
#        'mobile_network_provider', 'processor_response',
#        'kora_translated_processor_response', 'amount', 'amount_collected',
#        'is_fraud'],
#       dtype='object')

# %%
df.is_fraud.value_counts()
# Out:
# is_fraud
# 0    253523
# 1    143322
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# transaction_reference                 0
# payment_reference                     0
# merchant                              0
# customer_name                         0
# customer_email                        0
# customer_phone_number                 0
# merchant_bears_cost                   0
# tran_date                             0
# payment_created_at                    0
# payment_updated_at                    0
# for_disbursement_wallet               0
# account_created_date                  0
# account_risk_level                    0
# payment_source_type                   0
# processor                             0
# payment_status                        0
# payment_channel                       0
# payment_reversals_type                0
# currency                              0
# auth_model                            0
# mobile_number_for_mobile_money        0
# mobile_network_provider               0
# processor_response                    0
# kora_translated_processor_response    0
# amount                                0
# amount_collected                      0
# is_fraud                              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396845 entries, 0 to 396844
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   transaction_reference               396845 non-null  object
#  1   payment_reference                   396845 non-null  object
#  2   merchant                            396845 non-null  object
#  3   customer_name                       396845 non-null  object
#  4   customer_email                      396845 non-null  object
#  5   customer_phone_number               396845 non-null  object
#  6   merchant_bears_cost                 396845 non-null  int64
#  7   tran_date                           396845 non-null  object
#  8   payment_created_at                  396845 non-null  object
#  9   payment_updated_at                  396845 non-null  object
#  10  for_disbursement_wallet             396845 non-null  int64
#  11  account_created_date                396845 non-null  object
#  12  account_risk_level                  396845 non-null  object
#  13  payment_source_type                 396845 non-null  object
#  14  processor                           396845 non-null  object
#  15  payment_status                      396845 non-null  object
#  16  payment_channel                     396845 non-null  object
#  17  payment_reversals_type              396845 non-null  int64
#  18  currency                            396845 non-null  object
#  19  auth_model                          396845 non-null  object
#  20  mobile_number_for_mobile_money      396845 non-null  int64
#  21  mobile_network_provider             396845 non-null  object
#  22  processor_response                  396845 non-null  object
#  23  kora_translated_processor_response  396845 non-null  object
#  24  amount                              396845 non-null  float64
#  25  amount_collected                    396845 non-null  float64
#  26  is_fraud                            396845 non-null  int64
# dtypes: float64(2), int64(5), object(20)
# memory usage: 81.7+ MB

# %%
df.head()
# Out:
#   transaction_reference payment_reference    merchant    customer_name  \
# 0   KPY-CA-5xlpa6ZxSxHf         923438867  BLENET LTD  Emmanuel Norman
# 1   KPY-CA-bVBQDQuNVhsb         923446863  BLENET LTD    Edward Gyamfi
# 2   KPY-CA-YtBlORY4dc0S         923448600  BLENET LTD       Elom Ohene
# 3   KPY-CA-s93p6xaZ3TOJ         923449039  BLENET LTD   Benneth Pascal
# 4   KPY-CA-UjVz7bbxlKV0         923449546  BLENET LTD   Benneth Pascal
#
#                 customer_email customer_phone_number  merchant_bears_cost  \
# 0        iamnormkay@icloud.com        233543521075.0                    1
# 1     gyamfiedward98@gmail.com        233557469987.0                    1
# 2  humanitarianalarm@gmail.com        233245689134.0                    1
# 3           mrpubenr@gmail.com        233558163994.0                    1
# 4           mrpubenr@gmail.com        233558163994.0                    1
#
#              tran_date   payment_created_at   payment_updated_at  \
# 0  2024-08-26 16:03:35  2024-08-26 16:03:35  2024-08-26 16:15:17
# 1  2024-08-26 16:17:07  2024-08-26 16:17:07  2024-08-26 16:17:41
# 2  2024-08-26 16:20:13  2024-08-26 16:20:13  2024-08-26 16:21:04
# 3  2024-08-26 16:20:50  2024-08-26 16:20:50  2024-08-26 16:37:42
# 4  2024-08-26 16:21:46  2024-08-26 16:21:46  2024-08-26 16:22:39
#
#    for_disbursement_wallet account_created_date  account_risk_level  \
# 0                        0  2023-04-26 10:54:42  above_average_risk
# 1                        0  2023-04-26 10:54:42  above_average_risk
# 2                        0  2023-04-26 10:54:42  above_average_risk
# 3                        0  2023-04-26 10:54:42  above_average_risk
# 4                        0  2023-04-26 10:54:42  above_average_risk
#
#   payment_source_type processor payment_status payment_channel  \
# 0        mobile_money     nsano         failed             api
# 1        mobile_money     nsano        success             api
# 2        mobile_money     nsano        success             api
# 3        mobile_money     nsano         failed             api
# 4        mobile_money     nsano        success             api
#
#    payment_reversals_type currency  auth_model  \
# 0                       0      GHS  STK_PROMPT
# 1                       0      GHS  STK_PROMPT
# 2                       0      GHS  STK_PROMPT
# 3                       0      GHS  STK_PROMPT
# 4                       0      GHS  STK_PROMPT
#
#    mobile_number_for_mobile_money mobile_network_provider  \
# 0                    233543521075                     MTN
# 1                    233557469987                     MTN
# 2                    233245689134                     MTN
# 3                    233272525000                  Airtel
# 4                    233243721306                     MTN
#
#           processor_response       kora_translated_processor_response  amount  \
# 0        Transaction failed.  Charge attempt failed, please try again  468.05
# 1    Transaction successful.                        Charge successful  156.02
# 2    Transaction successful.                        Charge successful  156.02
# 3  Transaction id is invalid  Charge attempt failed, please try again  506.00
# 4    Transaction successful.                        Charge successful  506.00
#
#    amount_collected  is_fraud
# 0              0.00         0
# 1            156.02         0
# 2            156.02         0
# 3              0.00         0
# 4            506.00         0

# %%
df.to_csv('data/mob_money_preprocessed_2.csv', index=False)
